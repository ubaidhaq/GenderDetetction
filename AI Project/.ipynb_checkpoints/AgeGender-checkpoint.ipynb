# %%
# Import required modules
import cv2 as cv
import math
import time
import argparse

def getFaceBox(net, frame, conf_threshold=0.7):
    frameOpencvDnn = frame.copy()
    frameHeight = frameOpencvDnn.shape[0]
    frameWidth = frameOpencvDnn.shape[1]
    blob = cv.dnn.blobFromImage(frameOpencvDnn, 1.0, (300, 300), [104, 117, 123], True, False)

    net.setInput(blob)
    detections = net.forward()
    bboxes = []
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > conf_threshold:
            x1 = int(detections[0, 0, i, 3] * frameWidth)
            y1 = int(detections[0, 0, i, 4] * frameHeight)
            x2 = int(detections[0, 0, i, 5] * frameWidth)
            y2 = int(detections[0, 0, i, 6] * frameHeight)
            bboxes.append([x1, y1, x2, y2])
            cv.rectangle(frameOpencvDnn, (x1, y1), (x2, y2), (0, 255, 0), int(round(frameHeight/150)), 8)
    return frameOpencvDnn, bboxes


parser = argparse.ArgumentParser(description='Use this script to run age and gender recognition using OpenCV.')
parser.add_argument('--input', help='Path to input image or video file. Skip this argument to capture frames from a camera.')

args = parser.parse_known_args()[0]

faceProto = "opencv_face_detector.pbtxt"
faceModel = "opencv_face_detector_uint8.pb"

ageProto = "age_deploy.prototxt"
ageModel = "age_net.caffemodel"

genderProto = "gender_deploy.prototxt"
genderModel = "gender_net.caffemodel"

MODEL_MEAN_VALUES = (78.4263377603, 87.7689143744, 114.895847746)
ageList = ['(0-2)', '(4-6)', '(8-12)', '(15-20)', '(25-32)', '(38-43)', '(48-53)', '(60-100)']
genderList = ['Male', 'Female']

# Load network
ageNet = cv.dnn.readNet(ageModel, ageProto)
genderNet = cv.dnn.readNet(genderModel, genderProto)
faceNet = cv.dnn.readNet(faceModel, faceProto)

# Open a video file or an image file or a camera stream
cap = cv.VideoCapture(args.input if args.input else 0)
padding = 20
while cv.waitKey(1) < 0:
    # Read frame
    t = time.time()
    hasFrame, frame = cap.read()
    if not hasFrame:
        cv.waitKey()
        break

    frameFace, bboxes = getFaceBox(faceNet, frame)
    if not bboxes:
        print("No face Detected, Checking next frame")
        continue

    for bbox in bboxes:
        # print(bbox)
        face = frame[max(0,bbox[1]-padding):min(bbox[3]+padding,frame.shape[0]-1),max(0,bbox[0]-padding):min(bbox[2]+padding, frame.shape[1]-1)]

        blob = cv.dnn.blobFromImage(face, 1.0, (227, 227), MODEL_MEAN_VALUES, swapRB=False)
        genderNet.setInput(blob)
        genderPreds = genderNet.forward()
        gender = genderList[genderPreds[0].argmax()]
        # print("Gender Output : {}".format(genderPreds))
        print("Gender : {}, conf = {:.3f}".format(gender, genderPreds[0].max()))

        ageNet.setInput(blob)
        agePreds = ageNet.forward()
        age = ageList[agePreds[0].argmax()]
        print("Age Output : {}".format(agePreds))
        print("Age : {}, conf = {:.3f}".format(age, agePreds[0].max()))

        label = "{},{}".format(gender, age)
        cv.putText(frameFace, label, (bbox[0], bbox[1]-10), cv.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2, cv.LINE_AA)
        cv.imshow("Age Gender Demo", frameFace)
        # cv.imwrite("age-gender-out-{}".format(args.input),frameFace)
    print("time : {:.3f}".format(time.time() - t))
# Out:
# Gender : Male, conf = 0.586
# Age Output : [[1.0555396e-03 1.4518021e-04 1.0315882e-03 8.6389662e-04 1.4716096e-01
#   8.3022708e-01 9.4657391e-03 1.0050008e-02]]
# Age : (38-43), conf = 0.830
# time : 0.870
# Gender : Female, conf = 0.512
# Age Output : [[5.5851170e-04 9.6835647e-05 7.3272974e-04 7.7940460e-04 1.1131546e-01
#   8.6817831e-01 1.1250093e-02 7.0886421e-03]]
# Age : (38-43), conf = 0.868
# time : 0.171
# Gender : Female, conf = 0.889
# Age Output : [[5.0298707e-04 8.2073042e-05 5.3549360e-04 6.6326174e-04 9.8068513e-02
#   8.7866229e-01 1.2654697e-02 8.8306628e-03]]
# Age : (38-43), conf = 0.879
# time : 0.156
# Gender : Female, conf = 0.868
# Age Output : [[3.7952667e-04 8.1183454e-05 6.2972016e-04 7.6428399e-04 1.4360535e-01
#   8.3691198e-01 1.1356191e-02 6.2717563e-03]]
# Age : (38-43), conf = 0.837
# time : 0.150
# Gender : Female, conf = 0.841
# Age Output : [[3.0501513e-04 6.2936728e-05 5.4698769e-04 7.2206947e-04 1.2403425e-01
#   8.6088175e-01 8.5880756e-03 4.8590396e-03]]
# Age : (38-43), conf = 0.861
# time : 0.164
# No face Detected, Checking next frame
# Gender : Female, conf = 0.899
# Age Output : [[3.7442998e-04 6.7158697e-05 5.2509306e-04 6.4970605e-04 1.1436358e-01
#   8.6970669e-01 8.1640072e-03 6.1493390e-03]]
# Age : (38-43), conf = 0.870
# time : 0.153
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.980
# Age Output : [[2.3367419e-04 3.5612731e-05 3.3030650e-04 4.1209965e-04 6.4146645e-02
#   9.1780204e-01 8.8330097e-03 8.2066087e-03]]
# Age : (38-43), conf = 0.918
# time : 0.141
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.969
# Age Output : [[9.4894538e-05 1.5079934e-05 2.0019157e-04 2.9268939e-04 8.2802273e-02
#   9.0489280e-01 6.6545308e-03 5.0475607e-03]]
# Age : (38-43), conf = 0.905
# time : 0.158
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.964
# Age Output : [[7.92654464e-05 1.04343735e-05 1.43777084e-04 1.57549337e-04
#   3.44194844e-02 9.54916358e-01 5.57085779e-03 4.70230542e-03]]
# Age : (38-43), conf = 0.955
# time : 0.145
# Gender : Female, conf = 0.915
# Age Output : [[1.00234014e-04 1.20422274e-05 1.49033542e-04 1.58252340e-04
#   3.30852754e-02 9.55810606e-01 5.66319888e-03 5.02131786e-03]]
# Age : (38-43), conf = 0.956
# time : 0.141
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.964
# Age Output : [[1.20133402e-04 1.46156735e-05 1.98550639e-04 2.28342833e-04
#   5.22600673e-02 9.34886456e-01 6.53652800e-03 5.75530296e-03]]
# Age : (38-43), conf = 0.935
# time : 0.141
# Gender : Female, conf = 0.992
# Age Output : [[1.8034465e-04 2.1600090e-05 2.7843946e-04 3.2636515e-04 3.7475243e-02
#   9.4603086e-01 8.0722291e-03 7.6148342e-03]]
# Age : (38-43), conf = 0.946
# time : 0.152
# Gender : Female, conf = 0.990
# Age Output : [[1.2980991e-04 1.8071796e-05 2.5239633e-04 3.5825418e-04 5.0429069e-02
#   9.3435568e-01 8.7559344e-03 5.7008131e-03]]
# Age : (38-43), conf = 0.934
# time : 0.149
# Gender : Female, conf = 0.992
# Age Output : [[1.8287110e-04 2.0140611e-05 2.8446256e-04 3.5269099e-04 3.0161425e-02
#   9.5104730e-01 8.0384398e-03 9.9127078e-03]]
# Age : (38-43), conf = 0.951
# time : 0.154
# Gender : Female, conf = 0.992
# Age Output : [[1.23182544e-04 1.31070055e-05 1.99577305e-04 2.56823114e-04
#   3.38168181e-02 9.45504427e-01 8.65801144e-03 1.14279343e-02]]
# Age : (38-43), conf = 0.946
# time : 0.156
# No face Detected, Checking next frame
# Gender : Female, conf = 0.996
# Age Output : [[1.09277054e-04 1.21508838e-05 1.89423256e-04 2.41641013e-04
#   2.32676864e-02 9.54340398e-01 9.12967511e-03 1.27098681e-02]]
# Age : (38-43), conf = 0.954
# time : 0.154
# Gender : Female, conf = 0.993
# Age Output : [[1.4860024e-04 1.5064461e-05 2.5017234e-04 3.1116314e-04 2.9276175e-02
#   9.4250548e-01 1.0451479e-02 1.7041896e-02]]
# Age : (38-43), conf = 0.943
# time : 0.141
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.988
# Age Output : [[2.6097571e-04 3.7455149e-05 3.5191191e-04 4.9022672e-04 6.3751601e-02
#   9.1552675e-01 1.2206247e-02 7.3748846e-03]]
# Age : (38-43), conf = 0.916
# time : 0.152
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.981
# Age Output : [[1.3511689e-04 1.6744731e-05 1.7904297e-04 2.4763623e-04 3.2940205e-02
#   9.5187360e-01 6.8276650e-03 7.7799531e-03]]
# Age : (38-43), conf = 0.952
# time : 0.177
# No face Detected, Checking next frame
# Gender : Female, conf = 0.993
# Age Output : [[8.9371460e-05 1.0998798e-05 1.3335650e-04 1.8927336e-04 4.1254412e-02
#   9.4574577e-01 5.9717102e-03 6.6051115e-03]]
# Age : (38-43), conf = 0.946
# time : 0.146
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.974
# Age Output : [[7.1120026e-05 9.9511153e-06 1.2399780e-04 1.7688030e-04 2.9537823e-02
#   9.5769298e-01 6.6881361e-03 5.6990245e-03]]
# Age : (38-43), conf = 0.958
# time : 0.142
# Gender : Female, conf = 0.980
# Age Output : [[1.1802003e-04 1.5078612e-05 1.7462371e-04 2.0572206e-04 4.0638410e-02
#   9.4132382e-01 9.1245929e-03 8.3997613e-03]]
# Age : (38-43), conf = 0.941
# time : 0.141
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.990
# Age Output : [[2.3733484e-04 2.4450403e-05 3.0374271e-04 3.2352225e-04 6.8506874e-02
#   9.1469336e-01 8.1769014e-03 7.7337832e-03]]
# Age : (38-43), conf = 0.915
# time : 0.142
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.994
# Age Output : [[1.7796701e-04 2.3637165e-05 2.4687473e-04 3.5185169e-04 6.1223924e-02
#   9.2128861e-01 9.2498353e-03 7.4373502e-03]]
# Age : (38-43), conf = 0.921
# time : 0.145
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.996
# Age Output : [[1.8217378e-04 3.0818235e-05 2.6059602e-04 4.7882172e-04 7.2949737e-02
#   9.0643275e-01 1.1792434e-02 7.8727370e-03]]
# Age : (38-43), conf = 0.906
# time : 0.157
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.989
# Age Output : [[1.3584430e-04 3.3501394e-05 3.9505295e-04 6.6646247e-04 2.6654130e-01
#   7.1889770e-01 9.0005957e-03 4.3294858e-03]]
# Age : (38-43), conf = 0.719
# time : 0.155
# Gender : Female, conf = 0.917
# Age Output : [[2.1305711e-04 5.0739360e-05 4.7472987e-04 8.4742118e-04 1.9465195e-01
#   7.8674406e-01 1.1126300e-02 5.8917715e-03]]
# Age : (38-43), conf = 0.787
# time : 0.155
# Gender : Female, conf = 0.942
# Age Output : [[2.4540629e-04 5.9030157e-05 4.9073697e-04 9.9629327e-04 1.6244246e-01
#   8.2054669e-01 9.3748523e-03 5.8445740e-03]]
# Age : (38-43), conf = 0.821
# time : 0.143
# Gender : Female, conf = 0.957
# Age Output : [[9.6040043e-05 2.0862766e-05 2.8145191e-04 4.9004972e-04 1.0516209e-01
#   8.8436091e-01 6.0825357e-03 3.5060407e-03]]
# Age : (38-43), conf = 0.884
# time : 0.168
# Gender : Female, conf = 0.944
# Age Output : [[1.3471446e-04 3.1372972e-05 3.6561291e-04 6.2117644e-04 1.1967357e-01
#   8.6524659e-01 9.4328970e-03 4.4941199e-03]]
# Age : (38-43), conf = 0.865
# time : 0.154
# Gender : Female, conf = 0.814
# Age Output : [[1.0484783e-04 1.7894021e-05 2.0766961e-04 3.0048337e-04 4.9793769e-02
#   9.4393355e-01 3.3697742e-03 2.2719614e-03]]
# Age : (38-43), conf = 0.944
# time : 0.172
# Gender : Female, conf = 0.945
# Age Output : [[9.0649875e-05 1.5135524e-05 1.9093258e-04 2.6548919e-04 5.7028510e-02
#   9.3266177e-01 5.8317715e-03 3.9157700e-03]]
# Age : (38-43), conf = 0.933
# time : 0.168
# Gender : Female, conf = 0.977
# Age Output : [[8.87577626e-05 2.00238701e-05 2.52303696e-04 5.19418507e-04
#   1.04510136e-01 8.80671442e-01 8.95547681e-03 4.98246588e-03]]
# Age : (38-43), conf = 0.881
# time : 0.177
# Gender : Female, conf = 0.972
# Age Output : [[9.9595505e-05 1.8529481e-05 3.1956437e-04 4.5593426e-04 9.7574085e-02
#   8.9043355e-01 6.3346433e-03 4.7641522e-03]]
# Age : (38-43), conf = 0.890
# time : 0.178
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.995
# Age Output : [[2.2784225e-04 4.4615063e-05 4.0445648e-04 6.4343348e-04 1.1255835e-01
#   8.6501110e-01 1.2081509e-02 9.0286955e-03]]
# Age : (38-43), conf = 0.865
# time : 0.170
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.999
# Age Output : [[0.02035613 0.00102536 0.00301263 0.00126969 0.06691611 0.7746641
#   0.04381511 0.08894093]]
# Age : (38-43), conf = 0.775
# time : 0.159
# Gender : Female, conf = 0.996
# Age Output : [[3.2944905e-04 6.8675479e-05 4.6042935e-04 9.3351444e-04 6.4374670e-02
#   9.1925567e-01 8.2520330e-03 6.3255653e-03]]
# Age : (38-43), conf = 0.919
# time : 0.153
# Gender : Female, conf = 0.844
# Age Output : [[0.00444796 0.00466839 0.04005267 0.00371526 0.15549818 0.77375257
#   0.00922411 0.00864093]]
# Age : (38-43), conf = 0.774
# time : 0.141
# Gender : Female, conf = 0.949
# Age Output : [[0.00086627 0.0023724  0.034264   0.00269452 0.29873645 0.65405375
#   0.00380949 0.00320317]]
# Age : (38-43), conf = 0.654
# time : 0.160
# Gender : Female, conf = 0.967
# Age Output : [[0.00085913 0.00112393 0.00981554 0.00218024 0.2899459  0.68315876
#   0.00768581 0.00523075]]
# Age : (38-43), conf = 0.683
# time : 0.162
# Gender : Female, conf = 0.986
# Age Output : [[3.8435249e-04 2.2296247e-04 1.7002174e-03 1.5346919e-03 2.3498233e-01
#   7.4993545e-01 7.6904758e-03 3.5495388e-03]]
# Age : (38-43), conf = 0.750
# time : 0.151
# Gender : Female, conf = 0.996
# Age Output : [[7.6412965e-05 2.4440433e-05 4.0336465e-04 7.2451500e-04 2.0266674e-01
#   7.8125453e-01 8.8749547e-03 5.9750462e-03]]
# Age : (38-43), conf = 0.781
# time : 0.157
# Gender : Female, conf = 0.987
# Age Output : [[1.2186729e-04 5.1634841e-05 9.2438771e-04 9.6038962e-04 9.8779097e-02
#   8.8850379e-01 6.7036417e-03 3.9552259e-03]]
# Age : (38-43), conf = 0.889
# time : 0.160
# Gender : Female, conf = 0.979
# Age Output : [[2.4053200e-04 6.8523899e-05 8.0829830e-04 1.4885934e-03 8.5979745e-02
#   9.0026432e-01 6.3396585e-03 4.8102573e-03]]
# Age : (38-43), conf = 0.900
# time : 0.165
# Gender : Female, conf = 0.994
# Age Output : [[5.0873194e-05 1.1103545e-05 2.0345939e-04 5.3339649e-04 5.4221395e-02
#   9.3745208e-01 4.8860242e-03 2.6416529e-03]]
# Age : (38-43), conf = 0.937
# time : 0.155
# Gender : Female, conf = 0.992
# Age Output : [[7.0450602e-05 1.6100601e-05 2.5764745e-04 6.4772129e-04 5.2058522e-02
#   9.3941987e-01 5.3656017e-03 2.1641112e-03]]
# Age : (38-43), conf = 0.939
# time : 0.154
# Gender : Female, conf = 0.990
# Age Output : [[9.1538270e-05 1.8186920e-05 3.2708852e-04 7.0976705e-04 5.1313866e-02
#   9.3907112e-01 5.7387054e-03 2.7296415e-03]]
# Age : (38-43), conf = 0.939
# time : 0.153
# Gender : Female, conf = 0.991
# Age Output : [[1.8728091e-04 3.8330396e-05 4.3409655e-04 9.9009683e-04 4.9145553e-02
#   9.3823856e-01 7.3107765e-03 3.6554090e-03]]
# Age : (38-43), conf = 0.938
# time : 0.156
# Gender : Female, conf = 0.994
# Age Output : [[1.2523467e-04 2.8751529e-05 4.3733796e-04 9.6692401e-04 7.5285614e-02
#   9.1497314e-01 5.8601038e-03 2.3229630e-03]]
# Age : (38-43), conf = 0.915
# time : 0.139
# Gender : Female, conf = 0.993
# Age Output : [[6.0607188e-05 1.1922477e-05 2.3030136e-04 5.1918544e-04 4.7502581e-02
#   9.4348264e-01 5.4517151e-03 2.7410644e-03]]
# Age : (38-43), conf = 0.943
# time : 0.154
# Gender : Female, conf = 0.994
# Age Output : [[1.1025026e-04 2.0577738e-05 3.9246099e-04 7.1892480e-04 4.9218643e-02
#   9.3967736e-01 6.8456531e-03 3.0160742e-03]]
# Age : (38-43), conf = 0.940
# time : 0.156
# Gender : Female, conf = 0.993
# Age Output : [[2.4526846e-04 5.5384353e-05 1.0146472e-03 1.3134286e-03 1.4063857e-01
#   8.4873664e-01 4.2284089e-03 3.7676862e-03]]
# Age : (38-43), conf = 0.849
# time : 0.154
# Gender : Female, conf = 0.996
# Age Output : [[2.1761528e-04 6.3307969e-05 1.4748378e-03 1.3404307e-03 1.2712392e-01
#   8.6070120e-01 5.2763345e-03 3.8024257e-03]]
# Age : (38-43), conf = 0.861
# time : 0.155
# Gender : Female, conf = 0.999
# Age Output : [[1.5644464e-04 4.5431258e-05 6.9669902e-04 1.2288818e-03 1.4588568e-01
#   8.4450388e-01 4.4278852e-03 3.0550815e-03]]
# Age : (38-43), conf = 0.845
# time : 0.141
# Gender : Female, conf = 0.998
# Age Output : [[6.3766859e-04 2.2270081e-04 1.6976692e-03 3.4117866e-03 2.2350034e-01
#   7.6134628e-01 5.1159621e-03 4.0675830e-03]]
# Age : (38-43), conf = 0.761
# time : 0.156
# Gender : Female, conf = 0.998
# Age Output : [[3.67176166e-04 1.03689745e-04 1.08239544e-03 1.10567396e-03
#   1.26177728e-01 8.58766913e-01 6.33943640e-03 6.05705008e-03]]
# Age : (38-43), conf = 0.859
# time : 0.154
# Gender : Female, conf = 0.998
# Age Output : [[5.1179383e-04 2.3831079e-04 1.9136452e-03 1.5531089e-03 1.7654882e-01
#   8.0761909e-01 6.4915307e-03 5.1237275e-03]]
# Age : (38-43), conf = 0.808
# time : 0.156
# Gender : Female, conf = 0.999
# Age Output : [[5.2516063e-04 1.5074885e-04 1.0610023e-03 9.9054852e-04 1.3537382e-01
#   8.4666544e-01 8.0847256e-03 7.1486463e-03]]
# Age : (38-43), conf = 0.847
# time : 0.139
# Gender : Female, conf = 0.997
# Age Output : [[6.3237676e-04 2.7949130e-04 2.5544590e-03 2.1462429e-03 1.7123589e-01
#   8.0964994e-01 7.5100893e-03 5.9915693e-03]]
# Age : (38-43), conf = 0.810
# time : 0.138
# Gender : Female, conf = 0.998
# Age Output : [[2.7928659e-04 1.1478119e-04 2.0127320e-03 1.2302176e-03 1.2957644e-01
#   8.5645968e-01 5.7569793e-03 4.5698127e-03]]
# Age : (38-43), conf = 0.856
# time : 0.137
# Gender : Female, conf = 0.998
# Age Output : [[2.7261110e-04 7.9987549e-05 1.3686671e-03 1.1863196e-03 1.0581665e-01
#   8.8067657e-01 5.6963707e-03 4.9027917e-03]]
# Age : (38-43), conf = 0.881
# time : 0.146
# Gender : Female, conf = 0.999
# Age Output : [[7.8191678e-04 2.8787451e-04 1.9275302e-03 1.7782483e-03 1.0123203e-01
#   8.7862360e-01 8.9785829e-03 6.3902144e-03]]
# Age : (38-43), conf = 0.879
# time : 0.156
# Gender : Female, conf = 0.997
# Age Output : [[1.4811787e-03 7.5435045e-04 4.8842938e-03 2.4709222e-03 1.4552172e-01
#   8.2590955e-01 1.1770702e-02 7.2073075e-03]]
# Age : (38-43), conf = 0.826
# time : 0.139
# Gender : Female, conf = 0.997
# Age Output : [[7.0644449e-04 4.7180097e-04 4.8642312e-03 2.0136540e-03 1.4895900e-01
#   8.2477099e-01 1.0400420e-02 7.8135571e-03]]
# Age : (38-43), conf = 0.825
# time : 0.154
# Gender : Female, conf = 0.998
# Age Output : [[4.3249974e-04 2.3068544e-04 3.2745483e-03 1.8619251e-03 1.7035577e-01
#   8.1075734e-01 7.1550133e-03 5.9322775e-03]]
# Age : (38-43), conf = 0.811
# time : 0.156
# Gender : Female, conf = 0.998
# Age Output : [[0.00222619 0.00089698 0.00425224 0.00242906 0.13695292 0.8290161
#   0.01531466 0.00891188]]
# Age : (38-43), conf = 0.829
# time : 0.146
# Gender : Female, conf = 0.997
# Age Output : [[3.6296458e-04 1.4191090e-04 1.9195003e-03 1.2164325e-03 1.1621171e-01
#   8.6912936e-01 5.8811787e-03 5.1368698e-03]]
# Age : (38-43), conf = 0.869
# time : 0.160
# Gender : Female, conf = 0.997
# Age Output : [[6.9943460e-04 4.4953372e-04 3.2298258e-03 2.9032317e-03 1.7101340e-01
#   8.0998814e-01 7.2744675e-03 4.4419505e-03]]
# Age : (38-43), conf = 0.810
# time : 0.141
# Gender : Female, conf = 0.998
# Age Output : [[8.9272979e-04 6.1379431e-04 4.8335698e-03 1.6156780e-03 1.3897710e-01
#   8.3523279e-01 1.0185539e-02 7.6487432e-03]]
# Age : (38-43), conf = 0.835
# time : 0.136
# Gender : Female, conf = 0.996
# Age Output : [[0.00219595 0.00114493 0.00423062 0.00199705 0.10933698 0.85545135
#   0.01709028 0.00855292]]
# Age : (38-43), conf = 0.855
# time : 0.152
# Gender : Female, conf = 0.999
# Age Output : [[5.3098786e-04 2.3278171e-04 2.1493721e-03 1.8848039e-03 1.0953203e-01
#   8.7768215e-01 4.4787731e-03 3.5090095e-03]]
# Age : (38-43), conf = 0.878
# time : 0.164
# Gender : Female, conf = 0.998
# Age Output : [[3.3710999e-04 1.9157831e-04 2.4253582e-03 1.5111205e-03 1.9431745e-01
#   7.9169238e-01 5.5361190e-03 3.9888700e-03]]
# Age : (38-43), conf = 0.792
# time : 0.148
# Gender : Female, conf = 0.996
# Age Output : [[1.1881578e-04 4.9135160e-05 1.3199571e-03 1.2178787e-03 1.2542450e-01
#   8.6402673e-01 4.6890350e-03 3.1540028e-03]]
# Age : (38-43), conf = 0.864
# time : 0.149
# Gender : Female, conf = 0.999
# Age Output : [[7.3044721e-05 1.4635046e-05 2.9192376e-04 5.2853400e-04 8.7556444e-02
#   8.9958000e-01 7.3811007e-03 4.5742472e-03]]
# Age : (38-43), conf = 0.900
# time : 0.152
# Gender : Female, conf = 0.997
# Age Output : [[6.8654714e-05 1.5944006e-05 6.2097161e-04 5.0298200e-04 8.4129244e-02
#   9.0526623e-01 4.2333710e-03 5.1625962e-03]]
# Age : (38-43), conf = 0.905
# time : 0.140
# Gender : Female, conf = 0.998
# Age Output : [[1.8848333e-04 6.5758206e-05 1.1561618e-03 1.2637873e-03 1.9347396e-01
#   7.9766494e-01 3.3976312e-03 2.7892196e-03]]
# Age : (38-43), conf = 0.798
# time : 0.152
# Gender : Female, conf = 0.996
# Age Output : [[3.29774863e-04 6.86091662e-05 9.06034431e-04 1.08049426e-03
#   1.09537095e-01 8.75358999e-01 7.77001539e-03 4.94902441e-03]]
# Age : (38-43), conf = 0.875
# time : 0.152
# Gender : Female, conf = 0.998
# Age Output : [[1.8945495e-03 7.0505356e-04 2.6919385e-03 2.6892060e-03 1.9655225e-01
#   7.7942622e-01 1.1222869e-02 4.8179189e-03]]
# Age : (38-43), conf = 0.779
# time : 0.145
# Gender : Female, conf = 0.993
# Age Output : [[3.1832035e-04 7.0205650e-05 7.3381164e-04 8.1796001e-04 6.7225643e-02
#   9.1476059e-01 1.1554688e-02 4.5186868e-03]]
# Age : (38-43), conf = 0.915
# time : 0.154
# Gender : Female, conf = 0.991
# Age Output : [[8.4914638e-05 1.8444622e-05 2.7224608e-04 4.5852698e-04 4.7478482e-02
#   9.4203991e-01 7.3581212e-03 2.2893797e-03]]
# Age : (38-43), conf = 0.942
# time : 0.156
# Gender : Female, conf = 0.995
# Age Output : [[2.99225649e-04 7.54981011e-05 6.20733888e-04 1.12798729e-03
#   1.24759644e-01 8.61739576e-01 8.28166585e-03 3.09569365e-03]]
# Age : (38-43), conf = 0.862
# time : 0.155
# Gender : Female, conf = 0.998
# Age Output : [[1.1403615e-04 2.5063297e-05 2.4349250e-04 4.9332442e-04 8.2132913e-02
#   9.0926403e-01 5.2808067e-03 2.4463583e-03]]
# Age : (38-43), conf = 0.909
# time : 0.153
# Gender : Female, conf = 0.996
# Age Output : [[3.8956080e-04 9.5446958e-05 7.6274626e-04 1.2932114e-03 2.2411136e-01
#   7.6245075e-01 7.0962431e-03 3.8007118e-03]]
# Age : (38-43), conf = 0.762
# time : 0.173
# Gender : Female, conf = 0.996
# Age Output : [[2.1121962e-04 4.2431227e-05 4.1646880e-04 8.0993044e-04 1.1665685e-01
#   8.7372905e-01 5.3342306e-03 2.7997629e-03]]
# Age : (38-43), conf = 0.874
# time : 0.142
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.996
# Age Output : [[2.8098552e-04 5.7221219e-05 5.3407799e-04 8.2497206e-04 1.3336349e-01
#   8.5336018e-01 7.5102560e-03 4.0688654e-03]]
# Age : (38-43), conf = 0.853
# time : 0.173
# Gender : Female, conf = 0.990
# Age Output : [[1.8118871e-04 3.8676393e-05 4.4761281e-04 7.6004019e-04 8.8451035e-02
#   8.9812887e-01 8.2700616e-03 3.7225531e-03]]
# Age : (38-43), conf = 0.898
# time : 0.143
# Gender : Female, conf = 0.994
# Age Output : [[1.2814884e-04 2.6816053e-05 3.4510653e-04 6.3556491e-04 1.1024797e-01
#   8.7610984e-01 8.9277718e-03 3.5787860e-03]]
# Age : (38-43), conf = 0.876
# time : 0.145
# Gender : Female, conf = 0.992
# Age Output : [[1.7460852e-04 3.4973196e-05 3.4762593e-04 6.8595441e-04 8.5242592e-02
#   8.9986008e-01 9.1999071e-03 4.4542523e-03]]
# Age : (38-43), conf = 0.900
# time : 0.157
# Gender : Female, conf = 0.991
# Age Output : [[1.0535891e-04 1.9083922e-05 2.4020673e-04 4.7866648e-04 6.8699449e-02
#   9.1863972e-01 8.1237601e-03 3.6936924e-03]]
# Age : (38-43), conf = 0.919
# time : 0.156
# Gender : Female, conf = 0.996
# Age Output : [[1.3941286e-04 2.4651446e-05 2.7198737e-04 5.1160087e-04 7.8164421e-02
#   9.0871638e-01 8.0604367e-03 4.1111442e-03]]
# Age : (38-43), conf = 0.909
# time : 0.152
# Gender : Female, conf = 0.987
# Age Output : [[1.9147099e-04 3.7975249e-05 4.3814647e-04 7.2555634e-04 9.7581595e-02
#   8.8775885e-01 9.6683661e-03 3.5980777e-03]]
# Age : (38-43), conf = 0.888
# time : 0.150
# Gender : Female, conf = 0.966
# Age Output : [[7.6664342e-05 1.4658531e-05 2.1983322e-04 4.1697643e-04 8.5129037e-02
#   9.0271020e-01 8.2338108e-03 3.1988549e-03]]
# Age : (38-43), conf = 0.903
# time : 0.170
# Gender : Female, conf = 0.989
# Age Output : [[1.4450728e-04 2.7036171e-05 3.8273729e-04 7.1146613e-04 8.4525213e-02
#   9.0295655e-01 7.8320447e-03 3.4203907e-03]]
# Age : (38-43), conf = 0.903
# time : 0.143
# Gender : Female, conf = 0.988
# Age Output : [[1.49221596e-04 2.97201404e-05 3.75478412e-04 6.91550667e-04
#   1.12805456e-01 8.72870803e-01 9.06917453e-03 4.00854228e-03]]
# Age : (38-43), conf = 0.873
# time : 0.159
# Gender : Female, conf = 0.983
# Age Output : [[1.4874824e-04 3.0241770e-05 3.6970770e-04 6.9369405e-04 9.0959154e-02
#   8.9559084e-01 8.4973993e-03 3.7102657e-03]]
# Age : (38-43), conf = 0.896
# time : 0.187
# Gender : Female, conf = 0.989
# Age Output : [[7.1416798e-05 1.3196335e-05 2.3073726e-04 4.3215507e-04 8.1918895e-02
#   9.0750092e-01 6.4172917e-03 3.4154428e-03]]
# Age : (38-43), conf = 0.908
# time : 0.156
# Gender : Female, conf = 0.995
# Age Output : [[7.1312046e-05 1.2088578e-05 1.7362715e-04 3.5765549e-04 6.6583388e-02
#   9.2268282e-01 5.9108487e-03 4.2082053e-03]]
# Age : (38-43), conf = 0.923
# time : 0.157
# Gender : Female, conf = 0.995
# Age Output : [[9.2135662e-05 1.7821994e-05 2.4278127e-04 5.7526183e-04 8.9028470e-02
#   8.9781898e-01 7.7800849e-03 4.4444478e-03]]
# Age : (38-43), conf = 0.898
# time : 0.156
# Gender : Female, conf = 0.992
# Age Output : [[1.6265790e-04 3.1039304e-05 3.2823413e-04 5.3506583e-04 6.9348589e-02
#   9.2121190e-01 5.6879190e-03 2.6946159e-03]]
# Age : (38-43), conf = 0.921
# time : 0.140
# No face Detected, Checking next frame
# Gender : Female, conf = 0.985
# Age Output : [[2.3033579e-04 4.4117056e-05 4.1154234e-04 5.9099280e-04 6.4626157e-02
#   9.2164952e-01 8.5525103e-03 3.8947258e-03]]
# Age : (38-43), conf = 0.922
# time : 0.147
# Gender : Female, conf = 0.982
# Age Output : [[1.8528846e-04 3.4981345e-05 3.3600320e-04 4.6802289e-04 4.8718296e-02
#   9.3661553e-01 9.6755130e-03 3.9663310e-03]]
# Age : (38-43), conf = 0.937
# time : 0.148
# Gender : Female, conf = 0.996
# Age Output : [[2.0396849e-04 3.8822483e-05 3.0436760e-04 4.4819334e-04 5.8184300e-02
#   9.2267835e-01 1.2922317e-02 5.2196924e-03]]
# Age : (38-43), conf = 0.923
# time : 0.156
# Gender : Female, conf = 0.987
# Age Output : [[1.1318534e-04 2.0009002e-05 2.2687436e-04 2.8431899e-04 3.8714580e-02
#   9.4548172e-01 1.0798142e-02 4.3612542e-03]]
# Age : (38-43), conf = 0.945
# time : 0.151
# No face Detected, Checking next frame
# Gender : Female, conf = 0.981
# Age Output : [[7.5405653e-05 1.3557135e-05 1.8406476e-04 2.3791507e-04 3.2121968e-02
#   9.5190138e-01 1.0867116e-02 4.5985705e-03]]
# Age : (38-43), conf = 0.952
# time : 0.133
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.989
# Age Output : [[1.1806435e-04 2.0799969e-05 2.5244849e-04 4.0896947e-04 6.8124019e-02
#   9.1875875e-01 7.9886531e-03 4.3283682e-03]]
# Age : (38-43), conf = 0.919
# time : 0.162
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.980
# Age Output : [[2.1637963e-04 5.8778805e-05 5.1892578e-04 9.9255017e-04 1.8016769e-01
#   7.9879051e-01 1.3962715e-02 5.2924971e-03]]
# Age : (38-43), conf = 0.799
# time : 0.181
# Gender : Female, conf = 0.990
# Age Output : [[1.2907480e-04 2.6948323e-05 3.2796987e-04 6.3371548e-04 8.7159961e-02
#   8.9996761e-01 7.9319179e-03 3.8228999e-03]]
# Age : (38-43), conf = 0.900
# time : 0.171
# Gender : Female, conf = 0.992
# Age Output : [[9.7266573e-05 2.0924188e-05 3.4266547e-04 5.4156739e-04 1.5460789e-01
#   8.3132362e-01 8.0035562e-03 5.0625131e-03]]
# Age : (38-43), conf = 0.831
# time : 0.158
# Gender : Female, conf = 0.997
# Age Output : [[2.1837665e-04 4.2139331e-05 4.0487721e-04 6.0583069e-04 1.4884369e-01
#   8.3548319e-01 8.4023234e-03 5.9995283e-03]]
# Age : (38-43), conf = 0.835
# time : 0.154
# Gender : Female, conf = 0.995
# Age Output : [[1.7236096e-04 3.3319546e-05 4.0234992e-04 6.3435134e-04 1.5059653e-01
#   8.3513033e-01 7.7599292e-03 5.2707135e-03]]
# Age : (38-43), conf = 0.835
# time : 0.141
# Gender : Female, conf = 0.995
# Age Output : [[1.7946582e-04 3.4914654e-05 4.4794547e-04 7.1706204e-04 1.4268413e-01
#   8.4126228e-01 8.9271795e-03 5.7470235e-03]]
# Age : (38-43), conf = 0.841
# time : 0.154
# Gender : Female, conf = 0.991
# Age Output : [[1.6402817e-04 3.1397620e-05 3.4520542e-04 6.5151200e-04 1.2375917e-01
#   8.6205614e-01 8.6281952e-03 4.3644654e-03]]
# Age : (38-43), conf = 0.862
# time : 0.148
# Gender : Female, conf = 0.991
# Age Output : [[1.8298643e-04 3.5867255e-05 3.8294311e-04 6.2368333e-04 1.4874810e-01
#   8.3285958e-01 1.1123399e-02 6.0434295e-03]]
# Age : (38-43), conf = 0.833
# time : 0.156
# Gender : Female, conf = 0.995
# Age Output : [[1.8748145e-04 4.2037285e-05 4.6501425e-04 8.0852571e-04 1.8952346e-01
#   7.9274648e-01 1.1181788e-02 5.0452636e-03]]
# Age : (38-43), conf = 0.793
# time : 0.164
# Gender : Female, conf = 0.995
# Age Output : [[2.3559559e-04 4.6294073e-05 4.7371772e-04 7.9418672e-04 1.5102197e-01
#   8.3200622e-01 1.0465490e-02 4.9565961e-03]]
# Age : (38-43), conf = 0.832
# time : 0.143
# Gender : Female, conf = 0.986
# Age Output : [[1.07201755e-04 2.07143767e-05 3.34215089e-04 5.21922077e-04
#   1.26793027e-01 8.62682760e-01 6.43471628e-03 3.10549466e-03]]
# Age : (38-43), conf = 0.863
# time : 0.170
# Gender : Female, conf = 0.993
# Age Output : [[2.4857788e-04 5.9721988e-05 6.6733907e-04 9.2005101e-04 2.0012738e-01
#   7.8608865e-01 7.9200966e-03 3.9681667e-03]]
# Age : (38-43), conf = 0.786
# time : 0.142
# Gender : Female, conf = 0.992
# Age Output : [[2.0775305e-04 5.5187276e-05 5.7994039e-04 9.2840969e-04 2.4613130e-01
#   7.3752606e-01 1.0398234e-02 4.1730893e-03]]
# Age : (38-43), conf = 0.738
# time : 0.153
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.996
# Age Output : [[9.3734299e-05 1.6372693e-05 2.3021952e-04 3.0531990e-04 5.5359717e-02
#   9.2825162e-01 1.0264880e-02 5.4781009e-03]]
# Age : (38-43), conf = 0.928
# time : 0.146
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.991
# Age Output : [[9.3948838e-05 7.8787398e-06 8.9658846e-05 8.6795641e-05 1.2545162e-02
#   9.5669347e-01 1.0602079e-02 1.9881027e-02]]
# Age : (38-43), conf = 0.957
# time : 0.163
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.996
# Age Output : [[1.8782083e-04 1.5227487e-05 1.8301248e-04 1.8635193e-04 2.0615257e-02
#   9.6239960e-01 5.9150583e-03 1.0497603e-02]]
# Age : (38-43), conf = 0.962
# time : 0.155
# No face Detected, Checking next frame
# Gender : Female, conf = 0.994
# Age Output : [[2.6530708e-04 2.1354803e-05 2.2476456e-04 2.0654609e-04 1.5285272e-02
#   9.6108949e-01 7.9027880e-03 1.5004569e-02]]
# Age : (38-43), conf = 0.961
# time : 0.147
# No face Detected, Checking next frame
# Gender : Female, conf = 0.994
# Age Output : [[1.2376987e-04 1.0627522e-05 1.3162750e-04 1.5036708e-04 2.0004682e-02
#   9.6369660e-01 5.5216425e-03 1.0360546e-02]]
# Age : (38-43), conf = 0.964
# time : 0.165
# Gender : Female, conf = 0.993
# Age Output : [[3.1595718e-04 2.5031442e-05 2.4082413e-04 2.3336246e-04 1.6482670e-02
#   9.4691837e-01 9.2988443e-03 2.6484916e-02]]
# Age : (38-43), conf = 0.947
# time : 0.147
# No face Detected, Checking next frame
# Gender : Female, conf = 0.996
# Age Output : [[1.4800293e-04 1.2302873e-05 1.4756306e-04 1.5576850e-04 1.7006634e-02
#   9.5578200e-01 7.7057881e-03 1.9042043e-02]]
# Age : (38-43), conf = 0.956
# time : 0.148
# No face Detected, Checking next frame
# Gender : Female, conf = 0.972
# Age Output : [[9.9018194e-05 5.9745917e-06 9.3938630e-05 7.7851437e-05 8.5226111e-03
#   9.5169044e-01 8.4272120e-03 3.1082856e-02]]
# Age : (38-43), conf = 0.952
# time : 0.157
# Gender : Female, conf = 0.986
# Age Output : [[1.2034095e-04 9.2329656e-06 1.1666715e-04 1.0201550e-04 1.2453358e-02
#   9.6423554e-01 7.1019819e-03 1.5860906e-02]]
# Age : (38-43), conf = 0.964
# time : 0.166
# No face Detected, Checking next frame
# Gender : Female, conf = 0.979
# Age Output : [[5.9300939e-05 4.2611046e-06 6.3813968e-05 6.1445899e-05 7.2268485e-03
#   9.6719992e-01 7.1211876e-03 1.8263141e-02]]
# Age : (38-43), conf = 0.967
# time : 0.153
# No face Detected, Checking next frame
# Gender : Female, conf = 0.951
# Age Output : [[1.02184655e-04 7.82305142e-06 1.07687731e-04 8.94950936e-05
#   1.49824629e-02 9.65765238e-01 6.54598651e-03 1.23991687e-02]]
# Age : (38-43), conf = 0.966
# time : 0.152
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.956
# Age Output : [[2.23974246e-04 1.21738358e-05 1.32556524e-04 1.07574240e-04
#   1.22158844e-02 9.28388655e-01 1.11250095e-02 4.77941893e-02]]
# Age : (38-43), conf = 0.928
# time : 0.144
# Gender : Female, conf = 0.943
# Age Output : [[1.0674518e-04 7.1139057e-06 9.9831923e-05 7.8089972e-05 1.2601640e-02
#   9.6042693e-01 7.8923749e-03 1.8787250e-02]]
# Age : (38-43), conf = 0.960
# time : 0.156
# Gender : Female, conf = 0.979
# Age Output : [[1.01507168e-04 7.50556001e-06 1.01951795e-04 9.30621027e-05
#   1.52064161e-02 9.66088355e-01 6.28830912e-03 1.21129444e-02]]
# Age : (38-43), conf = 0.966
# time : 0.157
# Gender : Female, conf = 0.953
# Age Output : [[4.0797291e-05 3.7092736e-06 6.8002126e-05 7.6079654e-05 1.8094389e-02
#   9.6833378e-01 5.6717647e-03 7.7114291e-03]]
# Age : (38-43), conf = 0.968
# time : 0.171
# Gender : Female, conf = 0.993
# Age Output : [[2.0737630e-04 1.7433125e-05 1.9033912e-04 1.7736568e-04 1.8798364e-02
#   9.5305496e-01 9.7321952e-03 1.7821923e-02]]
# Age : (38-43), conf = 0.953
# time : 0.161
# Gender : Female, conf = 0.989
# Age Output : [[1.4406799e-04 1.0076168e-05 1.4732350e-04 1.2861087e-04 1.3472431e-02
#   9.6769464e-01 6.2735225e-03 1.2129330e-02]]
# Age : (38-43), conf = 0.968
# time : 0.150
# No face Detected, Checking next frame
# Gender : Female, conf = 0.989
# Age Output : [[6.49060312e-05 5.71398368e-06 8.60307337e-05 1.07050932e-04
#   1.44887585e-02 9.72134829e-01 4.58274037e-03 8.52994714e-03]]
# Age : (38-43), conf = 0.972
# time : 0.137
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.992
# Age Output : [[2.5784699e-04 1.7456727e-05 1.6924799e-04 1.4460900e-04 1.2659934e-02
#   9.3260247e-01 1.2065963e-02 4.2082548e-02]]
# Age : (38-43), conf = 0.933
# time : 0.159
# Gender : Female, conf = 0.948
# Age Output : [[8.5415020e-05 5.8114788e-06 7.7053097e-05 7.1094517e-05 9.6974783e-03
#   9.6240073e-01 7.9317270e-03 1.9730678e-02]]
# Age : (38-43), conf = 0.962
# time : 0.165
# Gender : Female, conf = 0.976
# Age Output : [[7.7695746e-05 5.5402475e-06 7.4697389e-05 7.3146228e-05 1.0353656e-02
#   9.6023554e-01 7.8945514e-03 2.1285176e-02]]
# Age : (38-43), conf = 0.960
# time : 0.137
# Gender : Female, conf = 0.967
# Age Output : [[1.3061005e-04 7.9530300e-06 9.9998753e-05 8.0594466e-05 8.7173404e-03
#   9.5515460e-01 8.4815454e-03 2.7327307e-02]]
# Age : (38-43), conf = 0.955
# time : 0.144
# No face Detected, Checking next frame
# Gender : Female, conf = 0.983
# Age Output : [[6.3919404e-05 4.2578226e-06 7.0442366e-05 6.9322290e-05 9.0648849e-03
#   9.5755863e-01 7.1324091e-03 2.6036158e-02]]
# Age : (38-43), conf = 0.958
# time : 0.139
# Gender : Female, conf = 0.995
# Age Output : [[2.5771325e-04 2.2204569e-05 1.9731822e-04 2.1177717e-04 1.8270617e-02
#   9.4951200e-01 8.6998558e-03 2.2828566e-02]]
# Age : (38-43), conf = 0.950
# time : 0.173
# No face Detected, Checking next frame
# Gender : Female, conf = 0.998
# Age Output : [[2.3761793e-04 1.4830187e-05 1.6510060e-04 1.4051986e-04 1.5109065e-02
#   9.3479913e-01 9.1535393e-03 4.0380195e-02]]
# Age : (38-43), conf = 0.935
# time : 0.153
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.999
# Age Output : [[8.3256850e-04 9.1629743e-05 6.7120220e-04 5.1405636e-04 5.8072206e-02
#   8.6644012e-01 1.8480698e-02 5.4897632e-02]]
# Age : (38-43), conf = 0.866
# time : 0.146
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.997
# Age Output : [[2.9856083e-04 4.4579985e-05 4.8052147e-04 4.5269734e-04 8.6191803e-02
#   8.9402860e-01 1.0669853e-02 7.8334277e-03]]
# Age : (38-43), conf = 0.894
# time : 0.159
# Gender : Female, conf = 0.996
# Age Output : [[6.06856600e-04 1.00053447e-04 7.04961247e-04 7.40802381e-04
#   1.12885416e-01 8.67830813e-01 1.12721054e-02 5.85896336e-03]]
# Age : (38-43), conf = 0.868
# time : 0.165
# Gender : Female, conf = 0.958
# Age Output : [[3.4820221e-04 6.8154310e-05 6.6504313e-04 7.6945435e-04 1.6086398e-01
#   8.1982744e-01 1.1999558e-02 5.4582125e-03]]
# Age : (38-43), conf = 0.820
# time : 0.158
# Gender : Female, conf = 0.986
# Age Output : [[5.7101913e-04 1.2394249e-04 8.4544974e-04 1.0983088e-03 1.7198695e-01
#   8.0331284e-01 1.5061617e-02 6.9998526e-03]]
# Age : (38-43), conf = 0.803
# time : 0.145
# Gender : Female, conf = 0.990
# Age Output : [[5.0942745e-04 9.9910249e-05 7.5637666e-04 9.1710786e-04 1.7480320e-01
#   8.0167842e-01 1.4446162e-02 6.7893760e-03]]
# Age : (38-43), conf = 0.802
# time : 0.176
# Gender : Female, conf = 0.978
# Age Output : [[4.2697613e-04 9.1853653e-05 7.5837586e-04 9.3758706e-04 1.3451618e-01
#   8.4205866e-01 1.4734962e-02 6.4754216e-03]]
# Age : (38-43), conf = 0.842
# time : 0.137
# Gender : Female, conf = 0.989
# Age Output : [[2.7808500e-04 5.8723457e-05 6.6951220e-04 7.4403692e-04 1.8532780e-01
#   7.9446405e-01 1.2200227e-02 6.2575573e-03]]
# Age : (38-43), conf = 0.794
# time : 0.149
# Gender : Female, conf = 0.994
# Age Output : [[4.0359725e-04 8.6878455e-05 6.3174847e-04 8.3389203e-04 1.8074580e-01
#   7.9620153e-01 1.2991913e-02 8.1046829e-03]]
# Age : (38-43), conf = 0.796
# time : 0.162
# Gender : Female, conf = 0.992
# Age Output : [[4.7276609e-04 8.9161025e-05 7.2597957e-04 8.6005137e-04 1.9039731e-01
#   7.9264116e-01 8.7121986e-03 6.1013279e-03]]
# Age : (38-43), conf = 0.793
# time : 0.158
# Gender : Female, conf = 0.995
# Age Output : [[7.0568180e-04 1.0926785e-04 9.4407343e-04 8.1268535e-04 2.0173991e-01
#   7.7295583e-01 1.2064541e-02 1.0667984e-02]]
# Age : (38-43), conf = 0.773
# time : 0.158
# Gender : Female, conf = 0.998
# Age Output : [[6.6042168e-04 9.1385060e-05 9.8200247e-04 8.1825530e-04 1.8649946e-01
#   7.9214454e-01 1.0111865e-02 8.6920550e-03]]
# Age : (38-43), conf = 0.792
# time : 0.167
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.999
# Age Output : [[1.4068120e-03 2.8549795e-04 1.9747773e-03 1.5224733e-03 1.0526875e-01
#   8.5203999e-01 2.1115208e-02 1.6386436e-02]]
# Age : (38-43), conf = 0.852
# time : 0.149
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 1.000
# Age Output : [[0.00317137 0.00106034 0.00445671 0.00244737 0.14282484 0.81351113
#   0.01995395 0.01257431]]
# Age : (38-43), conf = 0.814
# time : 0.152
# Gender : Female, conf = 0.998
# Age Output : [[0.00235985 0.00091891 0.00488255 0.00216704 0.15275562 0.79522854
#   0.02601229 0.01567519]]
# Age : (38-43), conf = 0.795
# time : 0.141
# Gender : Female, conf = 0.999
# Age Output : [[9.7413396e-04 2.0641177e-04 1.4206673e-03 1.0245041e-03 1.2964678e-01
#   8.2496673e-01 2.3893943e-02 1.7866829e-02]]
# Age : (38-43), conf = 0.825
# time : 0.172
# No face Detected, Checking next frame
# Gender : Female, conf = 0.999
# Age Output : [[6.3878368e-04 1.6404717e-04 1.3495748e-03 1.0338470e-03 1.0460863e-01
#   8.5545403e-01 2.3553506e-02 1.3197561e-02]]
# Age : (38-43), conf = 0.855
# time : 0.151
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.998
# Age Output : [[6.0600083e-04 1.7364419e-04 1.0413834e-03 1.0074027e-03 8.2094416e-02
#   8.8734889e-01 2.0243531e-02 7.4848430e-03]]
# Age : (38-43), conf = 0.887
# time : 0.137
# No face Detected, Checking next frame
# Gender : Female, conf = 0.998
# Age Output : [[5.8080745e-04 1.5357368e-04 1.0035391e-03 9.7103586e-04 9.5588885e-02
#   8.7278384e-01 2.0081146e-02 8.8373283e-03]]
# Age : (38-43), conf = 0.873
# time : 0.141
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.999
# Age Output : [[6.1514607e-04 1.4594388e-04 7.8291784e-04 8.6465123e-04 6.6290401e-02
#   8.9789677e-01 2.3453603e-02 9.9505316e-03]]
# Age : (38-43), conf = 0.898
# time : 0.151
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.999
# Age Output : [[1.0780317e-03 2.5745190e-04 1.5733193e-03 1.3695632e-03 1.3930447e-01
#   8.2125074e-01 2.2168508e-02 1.2997909e-02]]
# Age : (38-43), conf = 0.821
# time : 0.157
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# Gender : Female, conf = 0.999
# Age Output : [[8.9613232e-04 2.5581120e-04 1.4017492e-03 1.8769030e-03 2.2520638e-01
#   7.3526865e-01 2.2939518e-02 1.2154851e-02]]
# Age : (38-43), conf = 0.735
# time : 0.160
# Gender : Female, conf = 0.998
# Age Output : [[9.2028262e-04 2.5170745e-04 1.4522329e-03 1.3023159e-03 1.3355443e-01
#   8.2306391e-01 2.4376335e-02 1.5078794e-02]]
# Age : (38-43), conf = 0.823
# time : 0.183
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
# No face Detected, Checking next frame
